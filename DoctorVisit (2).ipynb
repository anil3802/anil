# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # 1.Load the dataset and display first 15 rows

# %%
df=pd.read_csv('DoctorVisit.csv')
df.head(15)
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %% [markdown]
# # 2.Display last 10 rows of the dataset

# %%
df.tail(10)
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 5180        5181       0    male  0.19    0.25        1        0       1
# 5181        5182       0    male  0.19    0.75        1        0       0
# 5182        5183       0  female  0.19    0.45        0        0       0
# 5183        5184       0    male  0.22    1.10        0        0       0
# 5184        5185       0    male  0.22    1.50        0        0       0
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# 5180      no      yes        no       no       no
# 5181      no       no        no       no       no
# ...

# %% [markdown]
# # 3.Display complete information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %% [markdown]
# # 4.Shape of the dataset

# %%
df.shape
# Out:
# (5190, 13)

# %% [markdown]
# # 5.Total no of people based on count of illness

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df['illness'].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %% [markdown]
# # 6.Visualize and analyze maximum and minimum income

# %%
y=list(df.income)
plt.boxplot(y)
plt.show()

# %% [markdown]
# # 7.Find out the no of days of reduced activity of male and female due to illness

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df.groupby(['gender','reduced']).mean()
# Out:
#                  Unnamed: 0    visits       age    income   illness    health
# gender reduced
# female 0        2524.038512  0.229322  0.465755  0.482735  1.462144  1.115098
#        1        1985.768421  0.400000  0.325684  0.542105  2.242105  1.610526
#        2        1622.618182  0.672727  0.391455  0.560182  2.236364  1.781818
#        3         997.311111  1.333333  0.403111  0.516000  2.733333  1.733333
#        4        1237.740741  0.851852  0.458889  0.466667  2.222222  2.074074
#        5        1169.055556  1.444444  0.401667  0.614444  2.222222  2.500000
#        6        1382.545455  1.363636  0.426364  0.622727  2.363636  1.363636
#        7        1034.846154  1.384615  0.436154  0.473462  2.653846  2.230769
#        8        1883.090909  1.090909  0.471818  0.404545  2.181818  4.000000
#        9        1349.000000  0.500000  0.570000  0.825000  3.000000  1.000000
#        10       1099.428571  2.142857  0.512857  0.421429  2.571429  2.000000
# ...

# %% [markdown]
# # 8.Correlation between different variables in dataset

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 9.Analyze how income of a patient affects the no of visits to the hospital

# %%
# relation between income and visits
plt.figure(figsize=(10,10))
plt.scatter(x='income',y='visits',data=df)
plt.xlabel('income')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %% [markdown]
# # 10.Count and visualize the no of males and females affected by the illness

# %%
sns.histplot(df.gender,bins=2)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %% [markdown]
# # 11.plot a horizontal bar chart to analyze the reduced days of activities illness based on gender

# %%
db=df.groupby('gender')['reduced'].sum().to_frame().reset_index()
#creating the bar chart
plt.barh(db['gender'],db['reduced'],color=['cornflowerblue','lightseagreen'])
#adding the aesthetics
plt.title('Bar Chart')
plt.xlabel('gender')
plt.ylabel('reduced activity')
plt.show()

# %% [markdown]
# # 12.Average age of persons to visit hospital

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df.groupby(['age']).mean()
# Out:
#        Unnamed: 0    visits    income   illness   reduced    health
# age
# 0.19  2387.335106  0.212766  0.418338  1.247340  0.519947  1.186170
# 0.22  2617.739489  0.201154  0.650932  1.197032  0.612531  1.098104
# 0.27  2748.388145  0.258126  0.847055  1.137667  0.745698  1.191205
# 0.32  2825.132890  0.242525  0.933123  1.222591  0.694352  1.488372
# 0.37  2804.308219  0.246575  0.887466  1.287671  1.239726  1.404110
# 0.42  2940.873016  0.317460  0.841984  1.206349  1.111111  1.158730
# 0.47  2857.834254  0.270718  0.748011  1.314917  0.552486  1.132597
# 0.52  2547.540541  0.414414  0.669775  1.608108  1.220721  1.346847
# 0.57  2527.311355  0.399267  0.523187  1.750916  1.062271  1.421245
# 0.62  2562.231013  0.354430  0.459937  1.677215  0.943038  1.212025
# 0.67  2735.968254  0.377778  0.349365  1.536508  1.041270  1.161905
# 0.72  2418.524331  0.482968  0.341350  2.009732  1.377129  1.255474

# %% [markdown]
# # 13.Histogram

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df['freepoor'].hist()
plt.xlabel('freepoor')
plt.ylabel('count')
plt.title('freepoor count')
plt.show()

# %%
df['age'].hist()
plt.xlabel('age')
plt.ylabel('count')
plt.title('age count')
plt.show()

# %%
df['gender'].hist()
plt.xlabel('gender')
plt.ylabel('count')
plt.title('gender count')
plt.show()

# %% [markdown]
# # 14.Check for Duplicate data

# %%
df.duplicated().any()
# Out:
# False

# %%
df=df.drop_duplicates()
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
#missing values
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 15.Top 10 visits based on number of times visited

# %%
top_10=df.nlargest(10,'visits').set_index('age')

# %%
top_10
# Out:
#       Unnamed: 0  visits  gender  income  illness  reduced  health private  \
# age
# 0.62         663       9    male    0.25        5       14      10      no
# 0.19          48       8  female    0.25        2        7       0      no
# 0.52         525       8    male    0.25        5       14       7      no
# 0.57         599       8    male    0.01        1        9       4      no
# 0.62         630       8  female    1.50        1       14       1     yes
# 0.67         743       8    male    0.25        2       14       5      no
# 0.22         115       7    male    0.00        1       14       1      no
# 0.27         334       7  female    0.90        1        3       0     yes
# 0.27         355       7  female    0.75        2        8       0      no
# 0.32         416       7  female    0.15        4       14       0     yes
#
#      freepoor freerepat nchronic lchronic
# age
# 0.62       no       yes       no      yes
# 0.19       no        no       no      yes
# ...

# %%
sns.barplot(x='visits',y=top_10.index,data=top_10)
# Out:
# <AxesSubplot:xlabel='visits', ylabel='age'>

# %% [markdown]
# # 16.Visualize the percentage of people getting govt health insurance due to low income,due to old age and also the perentage of people having private health insurance

# %%
# % of people getting govt insurance due to low income
label=['yes','no']
Y=df[df['freepoor']=='yes']
N=df[df['freepoor']=='no']
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt insurance due to low income")
plt.show()
# % of people having private insurance
Y=df[df['private']=='yes']
N=df[df['private']=='no']
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people having private insurance ")
plt.show()
# % of people getting govt insurance due to old age,disability or veteran status
Y=df[df['freerepat']=='yes']
N=df[df['freerepat']=='no']
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt insurance due to old age,disability or veteran status")
plt.show()
